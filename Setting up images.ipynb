# %% [markdown]
# DO NOT RUN: This is the entire file set up:
# <ul> Rescales the pictures to 256x256 pixels</ul>
# <ul> Detects faces and put them in a separate file. It runs a few times with different parameters </ul>
# <ul> Deleteing the detected pitures with faces form the labes </ul>
# <ul> Putting the corrected data in a training and testing files </ul>

# %%
#Loading images and rescaling them


img_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\images"
new_img_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Rescaled_images"

# Create the new directory for resized images if it doesn't exist
if not os.path.exists(new_img_dir):
   os.makedirs(new_img_dir)

# Loop over all files in the directory and resize images
for filename in os.listdir(img_dir):
    if filename.endswith(".jpg"):  # Assuming all images are in JPG format
        img_path = os.path.join(img_dir, filename)
        new_img_path = os.path.join(new_img_dir, filename)
        
        # Skip the image if it already exists in the rescaled directory
        if os.path.exists(new_img_path):
            continue
        
        try:
            # Load the image, convert it to RGB mode and resize it to 256x256 pixels
            img = Image.open(img_path).convert('RGB')
            img_resized = img.resize((256, 256))
            
            # Save the resized image with the original filename
            img_resized.save(new_img_path)
            
        except UnidentifiedImageError:
            print(f"Could not process image: {img_path}")
            continue



#Face-detection


# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier('C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/haarcascade_frontalface_default.xml')

# Set the input and output directories
input_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Rescaled images"
output_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Images with faces"

# Loop through each image in the input directory
for filename in os.listdir(input_dir):
    # Load the image
    img = cv2.imread(os.path.join(input_dir, filename))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=2, minNeighbors=8)
    
    # If at least one face is detected, copy the image to the output directory and draw a rectangle around each face
    if len(faces) > 0:
        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.imwrite(os.path.join(output_dir, filename), img)

# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier('C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/haarcascade_frontalface_default.xml')

# Set the input and output directories
input_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Rescaled images"
output_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\faces2"

# Loop through each image in the input directory
for filename in os.listdir(input_dir):
    # Load the image
    img = cv2.imread(os.path.join(input_dir, filename))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=3)
    
    # If at least one face is detected, copy the image to the output directory and draw a rectangle around each face
    if len(faces) > 0:
        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.imwrite(os.path.join(output_dir, filename), img)


# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier('C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/haarcascade_frontalface_default.xml')

# Set the input and output directories
input_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Rescaled images"
output_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\faces4"

# Loop through each image in the input directory
for filename in os.listdir(input_dir):
    # Load the image
    img = cv2.imread(os.path.join(input_dir, filename))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=10)
    
    # If at least one face is detected, copy the image to the output directory and draw a rectangle around each face
    if len(faces) > 0:
        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.imwrite(os.path.join(output_dir, filename), img)


# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier('C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/haarcascade_frontalface_default.xml')

# Set the input and output directories
input_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Rescaled images"
output_dir = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\faces3"

# Loop through each image in the input directory
for filename in os.listdir(input_dir):
    # Load the image
    img = cv2.imread(os.path.join(input_dir, filename))
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=3, minNeighbors=5)
    
    # If at least one face is detected, copy the image to the output directory and draw a rectangle around each face
    if len(faces) > 0:
        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.imwrite(os.path.join(output_dir, filename), img)



#Deleting the face detected images from the labels dataframe


# Set the directory path
dir_path = r"C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\not food"

# Get the file names in the directory
file_names = os.listdir(dir_path)

# Get only the image file names
not_food = [name for name in file_names if name.endswith((".jpg", ".jpeg", ".png"))]

# Delete image IDs in not_food from labels
labels = labels[~labels['image_id'].isin(not_food)]




#Deviding the dataset in train and test files

# Split the image files into training and testing sets
train_img, test_img = train_test_split(labels, test_size=0.2, random_state=1)

train_jpg = train_img["image_id"]
test_jpg = test_img["image_id"]

# Define the source directory for the images
src_dir = "C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/images/Rescaled_images"

# Define the destination directories for the training and testing sets
train_dir = "C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/images/Train_images"
test_dir = "C:/Users/Gebruiker/Documents/DataScience/ADA/Project/Food/images/Test_images"

# Move the training images to the training directory
for img_file in train_jpg:
    src_path = os.path.join(src_dir, img_file)
    dest_path = os.path.join(train_dir, img_file)
    try:
        shutil.move(src_path, dest_path)
    except FileNotFoundError:
        print(f"File {img_file} not found.")

# Move the testing images to the testing directory
for img_file in test_jpg:
    src_path = os.path.join(src_dir, img_file)
    dest_path = os.path.join(test_dir, img_file)
    try:
        shutil.move(src_path, dest_path)
    except FileNotFoundError:
        print(f"File {img_file} not found.")

# %% [markdown]
# Changing the names of the images

# %%
import os
import pandas as pd

# Load the dataframe
df = labels

# Loop over the images in the directory
for filename in os.listdir(r'C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Test_images'):
    # Get the image ID from the filename
    image_id = filename.split('.')[0]
    # Find the corresponding row in the dataframe
    row = df.loc[df['image_id'] == image_id]
    # If there's a match, rename the file
    if len(row) > 0:
        price_category = row.iloc[0]['price_category']
        new_filename = f"{price_category}_{image_id}.jpg"
        os.rename(os.path.join(r'C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Test_images', filename), os.path.join(r'C:\Users\Gebruiker\Documents\DataScience\ADA\Project\Food\images\Test_images', new_filename))
